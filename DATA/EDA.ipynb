# %%
import pandas as pd 
import numpy as np 
import plotly.express as px

# %%
titles = pd.read_csv(r'/Users/fercorreafort/Projects/Outlier_detection git/combined_titles.csv')

# %%
titles.select_dtypes(include=np.number).isna().sum()
# Out:
# release_year           0
# runtime                0
# seasons            19183
# imdb_score          2680
# imdb_votes          2721
# tmdb_popularity      789
# tmdb_score          3418
# dtype: int64

# %%
# Compute NaN counts and percentages for numeric columns
na_counts = titles.select_dtypes(include=np.number).isna().sum()
na_percent = 100 * na_counts / len(titles)
na_percent
